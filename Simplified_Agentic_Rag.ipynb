# %%
# %%
# %pip install langgraph openai chromadb pydantic tiktoken langchain
# Out:
# Requirement already satisfied: langgraph in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (0.4.8)
# Requirement already satisfied: openai in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (1.86.0)
# Requirement already satisfied: chromadb in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (1.0.12)
# Requirement already satisfied: pydantic in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (2.9.1)
# Requirement already satisfied: tiktoken in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (0.9.0)
# Collecting langchain
#   Downloading langchain-0.3.25-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langgraph) (0.3.65)
# Requirement already satisfied: langgraph-checkpoint>=2.0.26 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langgraph) (2.0.26)
# Requirement already satisfied: langgraph-prebuilt>=0.2.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langgraph) (0.2.2)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langgraph) (0.1.70)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from pydantic) (2.23.3)
# Requirement already satisfied: idna>=2.8 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from httpx<1,>=0.23.0->openai) (2021.10.8)
# Requirement already satisfied: httpcore==1.* in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.6)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (1.26.2)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (4.10.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (0.55b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from chromadb) (4.22.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from tiktoken) (2.32.3)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langchain) (0.3.45)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.41-cp39-cp39-win_amd64.whl.metadata (9.8 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langchain-core>=0.1->langgraph) (23.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (2.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.26.0->tiktoken) (2.0.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.26.0->tiktoken) (1.26.8)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.2.3-cp39-cp39-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: pyproject_hooks in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\saura\appdata\roaming\python\python39\site-packages (from build>=1.0.3->chromadb) (0.4.4)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from build>=1.0.3->chromadb) (7.1.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.17.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.18.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\saura\appdata\roaming\python\python39\site-packages (from kubernetes>=28.1.0->chromadb) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: ormsgpack<2.0.0,>=1.8.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from langgraph-checkpoint>=2.0.26->langgraph) (1.10.0)
# Requirement already satisfied: coloredlogs in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.55b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-instrumentation==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.33.0)
# Requirement already satisfied: filelock in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\saura\appdata\local\programs\python\python39\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading langchain-0.3.25-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------------------- -------- 0.8/1.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 4.8 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Downloading sqlalchemy-2.0.41-cp39-cp39-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 3.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 3.0 MB/s eta 0:00:00
# Downloading greenlet-3.2.3-cp39-cp39-win_amd64.whl (296 kB)
# Installing collected packages: greenlet, async-timeout, SQLAlchemy, langchain-text-splitters, langchain
#
#    ---------------- ----------------------- 2/5 [SQLAlchemy]
#    ---------------- ----------------------- 2/5 [SQLAlchemy]
#    ---------------- ----------------------- 2/5 [SQLAlchemy]
#    ---------------- ----------------------- 2/5 [SQLAlchemy]
#    ---------------- ----------------------- 2/5 [SQLAlchemy]
#    ---------------- ----------------------- 2/5 [SQLAlchemy]
#    ---------------- ----------------------- 2/5 [SQLAlchemy]
#    ---------------- ----------------------- 2/5 [SQLAlchemy]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain]
#    ---------------------------------------- 5/5 [langchain]
#
# Successfully installed SQLAlchemy-2.0.41 async-timeout-4.0.3 greenlet-3.2.3 langchain-0.3.25 langchain-text-splitters-0.3.8
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%
import os

# Set your API key here
os.environ["OPENAI_API_KEY"] = "Enter your OpenAI API Key"

# %%
# %%
import json
from openai import OpenAI
import chromadb
from chromadb.config import Settings
from openai import OpenAI
from openai import embeddings
from uuid import uuid4

# Load KB
with open("self_critique_loop_dataset.json", "r") as f:
    kb_data = json.load(f)

# Initialize Chroma
chroma_client = chromadb.Client(Settings(anonymized_telemetry=False))
collection = chroma_client.get_or_create_collection(name="kb_index")

# Embed and upsert
from openai import OpenAI

client = OpenAI()

def embed(text):
    return client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    ).data[0].embedding

for doc in kb_data:
    vector = embed(doc["answer_snippet"])
    collection.upsert(
        ids=[doc["doc_id"]],
        embeddings=[vector],
        documents=[doc["answer_snippet"]],
        metadatas=[{
            "source": doc["source"],
            "last_updated": doc["last_updated"]
        }]
    )

# %%
# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, List, Dict
from langchain_core.runnables import Runnable
from langchain_core.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI

# LangGraph State
class RAGState(TypedDict):
    user_question: str
    kb_hits: List[Dict]
    initial_answer: str
    critique_result: str
    refined_answer: str

# %%
# %%
def retrieve_kb(state: RAGState) -> RAGState:
    query = state["user_question"]
    query_vector = embed(query)
    results = collection.query(query_embeddings=[query_vector], n_results=5)

    kb_hits = []
    for i in range(len(results["ids"][0])):
        kb_hits.append({
            "doc_id": results["ids"][0][i],
            "answer_snippet": results["documents"][0][i],
            "source": results["metadatas"][0][i]["source"]
        })

    return {**state, "kb_hits": kb_hits}

# %%
# %%
llm = ChatOpenAI(model="gpt-4", temperature=0)

prompt_gen = PromptTemplate.from_template("""
You are a software best-practices assistant.

User Question:
{user_question}

Retrieved Snippets:
{kb_context}

Task:
Based on these snippets, write a concise answer to the user’s question.
Cite each snippet you use by its doc_id in square brackets (e.g., [KB004]).
Return only the answer text.
""")

def generate_answer(state: RAGState) -> RAGState:
    kb_context = "\n".join([f"[{hit['doc_id']}] {hit['answer_snippet']}" for hit in state["kb_hits"]])
    formatted_prompt = prompt_gen.format(user_question=state["user_question"], kb_context=kb_context)
    response = llm.invoke(formatted_prompt)
    return {**state, "initial_answer": response.content}

# %%
# %%
prompt_critique = PromptTemplate.from_template("""
You are a critical QA assistant. The user asked: {user_question}

Initial Answer:
{initial_answer}

KB Snippets:
{kb_context}

Task:
Determine if the initial answer fully addresses the question using only these snippets.
- If it does, respond exactly: COMPLETE
- If it misses any point or cites missing info, respond: REFINE: <short list of missing topic keywords>

Return exactly one line.
""")

def critique_answer(state: RAGState) -> RAGState:
    kb_context = "\n".join([f"[{hit['doc_id']}] {hit['answer_snippet']}" for hit in state["kb_hits"]])
    formatted_prompt = prompt_critique.format(
        user_question=state["user_question"],
        initial_answer=state["initial_answer"],
        kb_context=kb_context
    )
    response = llm.invoke(formatted_prompt)
    return {**state, "critique_result": response.content.strip()}

# %%
# %%
prompt_refine = PromptTemplate.from_template("""
You are a software best-practices assistant refining your answer. The user asked: {user_question}

Initial Answer:
{initial_answer}

Critique: {critique_result}

Additional Snippet:
[{extra_doc_id}] {extra_snippet}

Task:
Incorporate this snippet into the answer, covering the missing points.
Cite any snippet you use by doc_id in square brackets.
Return only the final refined answer.
""")

def refine_answer(state: RAGState) -> RAGState:
    if "REFINE" not in state["critique_result"]:
        return {**state, "refined_answer": state["initial_answer"]}
    
    missing_keywords = state["critique_result"].replace("REFINE:", "").strip()
    new_query = f"{state['user_question']} and information on {missing_keywords}"
    query_vector = embed(new_query)
    results = collection.query(query_embeddings=[query_vector], n_results=1)

    extra_doc_id = results["ids"][0][0]
    extra_snippet = results["documents"][0][0]

    formatted_prompt = prompt_refine.format(
        user_question=state["user_question"],
        initial_answer=state["initial_answer"],
        critique_result=state["critique_result"],
        extra_doc_id=extra_doc_id,
        extra_snippet=extra_snippet
    )
    response = llm.invoke(formatted_prompt)
    return {**state, "refined_answer": response.content}

# %%
# %%
workflow = StateGraph(RAGState)

workflow.add_node("retrieve_kb", retrieve_kb)
workflow.add_node("generate_answer", generate_answer)
workflow.add_node("critique_answer", critique_answer)
workflow.add_node("refine_answer", refine_answer)

workflow.set_entry_point("retrieve_kb")
workflow.add_edge("retrieve_kb", "generate_answer")
workflow.add_edge("generate_answer", "critique_answer")

def decide_next(state: RAGState):
    return "refine_answer" if "REFINE" in state["critique_result"] else END

workflow.add_conditional_edges("critique_answer", decide_next, {
    "refine_answer": "refine_answer",
    END: END
})

workflow.add_edge("refine_answer", END)

app = workflow.compile()

# %%
# %%
question = "What are best practices for caching?"

final_output = app.invoke({"user_question": question})

print(" Initial KB Hits:")
for hit in final_output["kb_hits"]:
    print(f"- [{hit['doc_id']}] {hit['answer_snippet']}")

print(" Initial Answer:")
print(final_output["initial_answer"])

print("\n Critique Result:")
print(final_output["critique_result"])

if "REFINE" in final_output["critique_result"]:
    print("\n Refined Answer:")
    print(final_output["refined_answer"])
    print("\n Final Answer:")
    print(final_output["refined_answer"])
else:
    print("\n Final Answer:")
    print(final_output["initial_answer"])
